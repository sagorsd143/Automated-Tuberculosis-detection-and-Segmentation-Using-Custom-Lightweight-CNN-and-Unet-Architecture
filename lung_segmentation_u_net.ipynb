# %% [markdown]
# # Lung segmentation from Chest X-Ray dataset
#
# **About the data**:
# - The dataset is made up of images and segmentated mask from two diffrent sources.
# - There is a slight abnormality in naming convention of masks.
# - Some images don't have their corresponding masks.
# - Images from the Shenzhen dataset has apparently smaller lungs as compared to the Montgomery dataset.
#
#
# ## Take a look at the dataset

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
from tqdm import tqdm
import os
from cv2 import imread, createCLAHE
import cv2
from glob import glob
# %matplotlib inline
import matplotlib.pyplot as plt

image_path = os.path.join("../input/data/Lung Segmentation/CXR_png")
mask_path = os.path.join("../input/data/Lung Segmentation/","masks/")

# %% [markdown]
# They can inspected the concerning dataset seperately [here](http://https://www.kaggle.com/kmader/pulmonary-chest-xray-abnormalities/home).

# %%
# we have 704 masks but 800 images. Hence we are going to
# make a 1-1 correspondance from mask to images, not the usual other way.
images = os.listdir(image_path)
mask = os.listdir(mask_path)
mask = [fName.split(".png")[0] for fName in mask]
image_file_name = [fName.split("_mask")[0] for fName in mask]

# %%
check = [i for i in mask if "mask" in i]
print("Total mask that has modified name:",len(check))
# Out:
# Total mask that has modified name: 566

# %% [markdown]
# Earlier I was going to train on the Shenzhen dataset while perform prediction on the Montgomery dataset. However, the nature of the data was diffrent in both the set. The images from Shenzhen dataset had smaller lung-to-image ratio as compared to the Montgomery dataset.
#
# Thus, I am loading the two dataset seperately which I combined once I got to know about the disparity.

# %%
testing_files = set(os.listdir(image_path)) & set(os.listdir(mask_path))
training_files = check

def getData(X_shape, flag = "test"):
    im_array = []
    mask_array = []

    if flag == "test":
        for i in tqdm(testing_files):
            im = cv2.resize(cv2.imread(os.path.join(image_path,i)),(X_shape,X_shape))[:,:,0]
            mask = cv2.resize(cv2.imread(os.path.join(mask_path,i)),(X_shape,X_shape))[:,:,0]

            im_array.append(im)
            mask_array.append(mask)

        return im_array,mask_array

    if flag == "train":
        for i in tqdm(training_files):
            im = cv2.resize(cv2.imread(os.path.join(image_path,i.split("_mask")[0]+".png")),(X_shape,X_shape))[:,:,0]
            mask = cv2.resize(cv2.imread(os.path.join(mask_path,i+".png")),(X_shape,X_shape))[:,:,0]

            im_array.append(im)
            mask_array.append(mask)

        return im_array,mask_array

# %%
#perform sanity check

def plotMask(X,y):
    sample = []

    for i in range(6):
        left = X[i]
        right = y[i]
        combined = np.hstack((left,right))
        sample.append(combined)


    for i in range(0,6,3):

        plt.figure(figsize=(25,10))

        plt.subplot(2,3,1+i)
        plt.imshow(sample[i])

        plt.subplot(2,3,2+i)
        plt.imshow(sample[i+1])


        plt.subplot(2,3,3+i)
        plt.imshow(sample[i+2])

        plt.show()

# %%
# Load training and testing data
dim = 256*2
X_train,y_train = getData(dim,flag="train")
X_test, y_test = getData(dim)
# Out:
# 100%|██████████| 566/566 [02:05<00:00,  4.46it/s]
# 100%|██████████| 138/138 [01:14<00:00,  1.95it/s]

# %% [markdown]
# # Perform Sanity Check
#
# It is prudent to perform sanity check of the data correspondance. It become a routine check-up after a while but it is very crucial to check if we had made a mistake in loading the data.

# %%
print("training set")
plotMask(X_train,y_train)
print("testing set")
plotMask(X_test,y_test)
# Out:
# training set
# testing set

# %% [markdown]
# Both the sets looks correct. Let's combine them and further use them as a unified dataset.

# %%
X_train = np.array(X_train).reshape(len(X_train),dim,dim,1)
y_train = np.array(y_train).reshape(len(y_train),dim,dim,1)
X_test = np.array(X_test).reshape(len(X_test),dim,dim,1)
y_test = np.array(y_test).reshape(len(y_test),dim,dim,1)
assert X_train.shape == y_train.shape
assert X_test.shape == y_test.shape
images = np.concatenate((X_train,X_test),axis=0)
mask  = np.concatenate((y_train,y_test),axis=0)

# %% [markdown]
# ## Define  the network and callbacks
#
# I am going to use my favourite segmentation network - U-Nets. You can read about them [here](https://arxiv.org/abs/1505.04597).

# %%
from keras.models import *
from keras.layers import *
from keras.optimizers import *
from keras import backend as keras
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, LearningRateScheduler


def dice_coef(y_true, y_pred):
    y_true_f = keras.flatten(y_true)
    y_pred_f = keras.flatten(y_pred)
    intersection = keras.sum(y_true_f * y_pred_f)
    return (2. * intersection + 1) / (keras.sum(y_true_f) + keras.sum(y_pred_f) + 1)

def dice_coef_loss(y_true, y_pred):
    return -dice_coef(y_true, y_pred)

def unet(input_size=(256,256,1)):
    inputs = Input(input_size)

    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(inputs)
    conv1 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)

    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(pool1)
    conv2 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)

    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(pool2)
    conv3 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)

    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(pool3)
    conv4 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(conv4)

    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(pool4)
    conv5 = Conv2D(512, (3, 3), activation='relu', padding='same')(conv5)

    up6 = concatenate([Conv2DTranspose(256, (2, 2), strides=(2, 2), padding='same')(conv5), conv4], axis=3)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(up6)
    conv6 = Conv2D(256, (3, 3), activation='relu', padding='same')(conv6)

    up7 = concatenate([Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(conv6), conv3], axis=3)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(up7)
    conv7 = Conv2D(128, (3, 3), activation='relu', padding='same')(conv7)

    up8 = concatenate([Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(conv7), conv2], axis=3)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(up8)
    conv8 = Conv2D(64, (3, 3), activation='relu', padding='same')(conv8)

    up9 = concatenate([Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(conv8), conv1], axis=3)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(up9)
    conv9 = Conv2D(32, (3, 3), activation='relu', padding='same')(conv9)

    conv10 = Conv2D(1, (1, 1), activation='sigmoid')(conv9)

    return Model(inputs=[inputs], outputs=[conv10])
# Out:
# Using TensorFlow backend.

# %% [markdown]
# #### Compile and train the Unet Model

# %%
model = unet(input_size=(512,512,1))
model.compile(optimizer=Adam(lr=1e-5), loss=dice_coef_loss,
                  metrics=[dice_coef, 'binary_accuracy'])
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 512, 512, 1)  0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 512, 512, 32) 320         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 512, 512, 32) 9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 256, 256, 32) 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 256, 256, 64) 18496       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 256, 256, 64) 36928       conv2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 128, 128, 64) 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 128, 128, 128 147584      conv2d_5[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 64, 64, 128)  0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 64, 64, 256)  590080      conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 32, 32, 256)  0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  2359808     conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 64, 64, 256)  524544      conv2d_10[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           conv2d_transpose_1[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 128, 128, 128 131200      conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           conv2d_transpose_2[0][0]
#                                                                  conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 128, 128, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 128, 128, 128 147584      conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 256, 256, 64) 32832       conv2d_14[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           conv2d_transpose_3[0][0]
#                                                                  conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 512, 512, 32) 8224        conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 512, 512, 64) 0           conv2d_transpose_4[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 512, 512, 32) 18464       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 512, 512, 32) 9248        conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 512, 512, 1)  33          conv2d_18[0][0]
# ==================================================================================================
# Total params: 7,759,521
# Trainable params: 7,759,521
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ## Callbacks, Early Stopping and Reduced LR

# %%
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, EarlyStopping, ReduceLROnPlateau
weight_path="{}_weights.best.hdf5".format('cxr_reg')

checkpoint = ModelCheckpoint(weight_path, monitor='val_loss', verbose=1,
                             save_best_only=True, mode='min', save_weights_only = True)

reduceLROnPlat = ReduceLROnPlateau(monitor='val_loss', factor=0.5,
                                   patience=3,
                                   verbose=1, mode='min', epsilon=0.0001, cooldown=2, min_lr=1e-6)
early = EarlyStopping(monitor="val_loss",
                      mode="min",
                      patience=15) # probably needs to be more patient, but kaggle time is limited
callbacks_list = [checkpoint, early, reduceLROnPlat]
# Out:
# /opt/conda/lib/python3.6/site-packages/Keras-2.2.4-py3.6.egg/keras/callbacks.py:1334: UserWarning: `epsilon` argument is deprecated and will be removed, use `min_delta` instead.
#   warnings.warn('`epsilon` argument is deprecated and '

# %% [markdown]
# #### Train the model
#
# I intially used a 60-40 train-test spit and got a loss of -0.97. However, the better way to do it is 80-10-10 train-test-validation spit. Below I am roughly doing the later.

# %%
from IPython.display import clear_output
from keras.optimizers import Adam
from sklearn.model_selection import train_test_split

model.compile(optimizer=Adam(lr=2e-4),
              loss=[dice_coef_loss],
           metrics = [dice_coef, 'binary_accuracy'])

train_vol, validation_vol, train_seg, validation_seg = train_test_split((images-127.0)/127.0,
                                                            (mask>127).astype(np.float32),
                                                            test_size = 0.1,random_state = 2018)

train_vol, test_vol, train_seg, test_seg = train_test_split(train_vol,train_seg,
                                                            test_size = 0.1,
                                                            random_state = 2018)

loss_history = model.fit(x = train_vol,
                       y = train_seg,
                         batch_size = 16,
                  epochs = 50,
                  validation_data =(test_vol,test_seg) ,
                  callbacks=callbacks_list)
# Out:
# Train on 569 samples, validate on 64 samples
# Epoch 1/50
# 569/569 [==============================] - 31s 55ms/step - loss: -0.3824 - dice_coef: 0.3824 - binary_accuracy: 0.5329 - val_loss: -0.4934 - val_dice_coef: 0.4934 - val_binary_accuracy: 0.6781
#
# Epoch 00001: val_loss improved from inf to -0.49342, saving model to cxr_reg_weights.best.hdf5
# Epoch 2/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.5748 - dice_coef: 0.5748 - binary_accuracy: 0.7541 - val_loss: -0.6671 - val_dice_coef: 0.6671 - val_binary_accuracy: 0.8255
#
# Epoch 00002: val_loss improved from -0.49342 to -0.66710, saving model to cxr_reg_weights.best.hdf5
# Epoch 3/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.7469 - dice_coef: 0.7469 - binary_accuracy: 0.8694 - val_loss: -0.7181 - val_dice_coef: 0.7181 - val_binary_accuracy: 0.8109
#
# Epoch 00003: val_loss improved from -0.66710 to -0.71809, saving model to cxr_reg_weights.best.hdf5
# Epoch 4/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.8017 - dice_coef: 0.8017 - binary_accuracy: 0.8962 - val_loss: -0.8718 - val_dice_coef: 0.8718 - val_binary_accuracy: 0.9358
#
# Epoch 00004: val_loss improved from -0.71809 to -0.87182, saving model to cxr_reg_weights.best.hdf5
# Epoch 5/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.8742 - dice_coef: 0.8742 - binary_accuracy: 0.9353 - val_loss: -0.8925 - val_dice_coef: 0.8925 - val_binary_accuracy: 0.9475
#
# Epoch 00005: val_loss improved from -0.87182 to -0.89253, saving model to cxr_reg_weights.best.hdf5
# Epoch 6/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.8704 - dice_coef: 0.8704 - binary_accuracy: 0.9350 - val_loss: -0.8746 - val_dice_coef: 0.8746 - val_binary_accuracy: 0.9383
#
# Epoch 00006: val_loss did not improve from -0.89253
# Epoch 7/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.8942 - dice_coef: 0.8942 - binary_accuracy: 0.9463 - val_loss: -0.9204 - val_dice_coef: 0.9204 - val_binary_accuracy: 0.9608
#
# Epoch 00007: val_loss improved from -0.89253 to -0.92041, saving model to cxr_reg_weights.best.hdf5
# Epoch 8/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9204 - dice_coef: 0.9204 - binary_accuracy: 0.9598 - val_loss: -0.9331 - val_dice_coef: 0.9331 - val_binary_accuracy: 0.9662
#
# Epoch 00008: val_loss improved from -0.92041 to -0.93308, saving model to cxr_reg_weights.best.hdf5
# Epoch 9/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9285 - dice_coef: 0.9285 - binary_accuracy: 0.9641 - val_loss: -0.9458 - val_dice_coef: 0.9458 - val_binary_accuracy: 0.9728
#
# Epoch 00009: val_loss improved from -0.93308 to -0.94582, saving model to cxr_reg_weights.best.hdf5
# Epoch 10/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9404 - dice_coef: 0.9404 - binary_accuracy: 0.9700 - val_loss: -0.9531 - val_dice_coef: 0.9531 - val_binary_accuracy: 0.9765
#
# Epoch 00010: val_loss improved from -0.94582 to -0.95312, saving model to cxr_reg_weights.best.hdf5
# Epoch 11/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9439 - dice_coef: 0.9439 - binary_accuracy: 0.9717 - val_loss: -0.9543 - val_dice_coef: 0.9543 - val_binary_accuracy: 0.9771
#
# Epoch 00011: val_loss improved from -0.95312 to -0.95426, saving model to cxr_reg_weights.best.hdf5
# Epoch 12/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9481 - dice_coef: 0.9481 - binary_accuracy: 0.9740 - val_loss: -0.9563 - val_dice_coef: 0.9563 - val_binary_accuracy: 0.9777
#
# Epoch 00012: val_loss improved from -0.95426 to -0.95626, saving model to cxr_reg_weights.best.hdf5
# Epoch 13/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9473 - dice_coef: 0.9473 - binary_accuracy: 0.9735 - val_loss: -0.9546 - val_dice_coef: 0.9546 - val_binary_accuracy: 0.9775
#
# Epoch 00013: val_loss did not improve from -0.95626
# Epoch 14/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9475 - dice_coef: 0.9475 - binary_accuracy: 0.9736 - val_loss: -0.9551 - val_dice_coef: 0.9551 - val_binary_accuracy: 0.9777
#
# Epoch 00014: val_loss did not improve from -0.95626
# Epoch 15/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9526 - dice_coef: 0.9526 - binary_accuracy: 0.9762 - val_loss: -0.9614 - val_dice_coef: 0.9614 - val_binary_accuracy: 0.9806
#
# Epoch 00015: val_loss improved from -0.95626 to -0.96141, saving model to cxr_reg_weights.best.hdf5
# Epoch 16/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9557 - dice_coef: 0.9557 - binary_accuracy: 0.9777 - val_loss: -0.9586 - val_dice_coef: 0.9586 - val_binary_accuracy: 0.9794
#
# Epoch 00016: val_loss did not improve from -0.96141
# Epoch 17/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9573 - dice_coef: 0.9573 - binary_accuracy: 0.9785 - val_loss: -0.9630 - val_dice_coef: 0.9630 - val_binary_accuracy: 0.9813
#
# Epoch 00017: val_loss improved from -0.96141 to -0.96301, saving model to cxr_reg_weights.best.hdf5
# Epoch 18/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9570 - dice_coef: 0.9570 - binary_accuracy: 0.9784 - val_loss: -0.9579 - val_dice_coef: 0.9579 - val_binary_accuracy: 0.9783
#
# Epoch 00018: val_loss did not improve from -0.96301
# Epoch 19/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9565 - dice_coef: 0.9565 - binary_accuracy: 0.9781 - val_loss: -0.9626 - val_dice_coef: 0.9626 - val_binary_accuracy: 0.9810
#
# Epoch 00019: val_loss did not improve from -0.96301
# Epoch 20/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9586 - dice_coef: 0.9586 - binary_accuracy: 0.9792 - val_loss: -0.9630 - val_dice_coef: 0.9630 - val_binary_accuracy: 0.9811
#
# Epoch 00020: val_loss did not improve from -0.96301
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 9.999999747378752e-05.
# Epoch 21/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9602 - dice_coef: 0.9602 - binary_accuracy: 0.9800 - val_loss: -0.9639 - val_dice_coef: 0.9639 - val_binary_accuracy: 0.9819
#
# Epoch 00021: val_loss improved from -0.96301 to -0.96386, saving model to cxr_reg_weights.best.hdf5
# Epoch 22/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9614 - dice_coef: 0.9614 - binary_accuracy: 0.9805 - val_loss: -0.9634 - val_dice_coef: 0.9634 - val_binary_accuracy: 0.9817
#
# Epoch 00022: val_loss did not improve from -0.96386
# Epoch 23/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9608 - dice_coef: 0.9608 - binary_accuracy: 0.9803 - val_loss: -0.9656 - val_dice_coef: 0.9656 - val_binary_accuracy: 0.9826
#
# Epoch 00023: val_loss improved from -0.96386 to -0.96558, saving model to cxr_reg_weights.best.hdf5
# Epoch 24/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9619 - dice_coef: 0.9619 - binary_accuracy: 0.9808 - val_loss: -0.9658 - val_dice_coef: 0.9658 - val_binary_accuracy: 0.9827
#
# Epoch 00024: val_loss improved from -0.96558 to -0.96581, saving model to cxr_reg_weights.best.hdf5
# Epoch 25/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9623 - dice_coef: 0.9623 - binary_accuracy: 0.9810 - val_loss: -0.9657 - val_dice_coef: 0.9657 - val_binary_accuracy: 0.9827
#
# Epoch 00025: val_loss did not improve from -0.96581
# Epoch 26/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9626 - dice_coef: 0.9626 - binary_accuracy: 0.9812 - val_loss: -0.9659 - val_dice_coef: 0.9659 - val_binary_accuracy: 0.9826
#
# Epoch 00026: val_loss improved from -0.96581 to -0.96586, saving model to cxr_reg_weights.best.hdf5
# Epoch 27/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9621 - dice_coef: 0.9621 - binary_accuracy: 0.9810 - val_loss: -0.9663 - val_dice_coef: 0.9663 - val_binary_accuracy: 0.9829
#
# Epoch 00027: val_loss improved from -0.96586 to -0.96629, saving model to cxr_reg_weights.best.hdf5
# Epoch 28/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9630 - dice_coef: 0.9630 - binary_accuracy: 0.9814 - val_loss: -0.9662 - val_dice_coef: 0.9662 - val_binary_accuracy: 0.9830
#
# Epoch 00028: val_loss did not improve from -0.96629
# Epoch 29/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9636 - dice_coef: 0.9636 - binary_accuracy: 0.9817 - val_loss: -0.9665 - val_dice_coef: 0.9665 - val_binary_accuracy: 0.9831
#
# Epoch 00029: val_loss improved from -0.96629 to -0.96652, saving model to cxr_reg_weights.best.hdf5
# Epoch 30/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9635 - dice_coef: 0.9635 - binary_accuracy: 0.9816 - val_loss: -0.9665 - val_dice_coef: 0.9665 - val_binary_accuracy: 0.9831
#
# Epoch 00030: val_loss did not improve from -0.96652
# Epoch 31/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9642 - dice_coef: 0.9642 - binary_accuracy: 0.9819 - val_loss: -0.9665 - val_dice_coef: 0.9665 - val_binary_accuracy: 0.9831
#
# Epoch 00031: val_loss improved from -0.96652 to -0.96655, saving model to cxr_reg_weights.best.hdf5
# Epoch 32/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9644 - dice_coef: 0.9644 - binary_accuracy: 0.9821 - val_loss: -0.9656 - val_dice_coef: 0.9656 - val_binary_accuracy: 0.9826
#
# Epoch 00032: val_loss did not improve from -0.96655
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# Epoch 33/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9649 - dice_coef: 0.9649 - binary_accuracy: 0.9823 - val_loss: -0.9664 - val_dice_coef: 0.9664 - val_binary_accuracy: 0.9830
#
# Epoch 00033: val_loss did not improve from -0.96655
# Epoch 34/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9650 - dice_coef: 0.9650 - binary_accuracy: 0.9824 - val_loss: -0.9667 - val_dice_coef: 0.9667 - val_binary_accuracy: 0.9832
#
# Epoch 00034: val_loss improved from -0.96655 to -0.96673, saving model to cxr_reg_weights.best.hdf5
# Epoch 35/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9653 - dice_coef: 0.9653 - binary_accuracy: 0.9825 - val_loss: -0.9669 - val_dice_coef: 0.9669 - val_binary_accuracy: 0.9833
#
# Epoch 00035: val_loss improved from -0.96673 to -0.96688, saving model to cxr_reg_weights.best.hdf5
# Epoch 36/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9654 - dice_coef: 0.9654 - binary_accuracy: 0.9826 - val_loss: -0.9664 - val_dice_coef: 0.9664 - val_binary_accuracy: 0.9831
#
# Epoch 00036: val_loss did not improve from -0.96688
# Epoch 37/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9658 - dice_coef: 0.9658 - binary_accuracy: 0.9827 - val_loss: -0.9667 - val_dice_coef: 0.9667 - val_binary_accuracy: 0.9832
#
# Epoch 00037: val_loss did not improve from -0.96688
# Epoch 38/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9654 - dice_coef: 0.9654 - binary_accuracy: 0.9826 - val_loss: -0.9669 - val_dice_coef: 0.9669 - val_binary_accuracy: 0.9832
#
# Epoch 00038: val_loss did not improve from -0.96688
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-05.
# Epoch 39/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9662 - dice_coef: 0.9662 - binary_accuracy: 0.9830 - val_loss: -0.9669 - val_dice_coef: 0.9669 - val_binary_accuracy: 0.9832
#
# Epoch 00039: val_loss improved from -0.96688 to -0.96692, saving model to cxr_reg_weights.best.hdf5
# Epoch 40/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9665 - dice_coef: 0.9665 - binary_accuracy: 0.9831 - val_loss: -0.9670 - val_dice_coef: 0.9670 - val_binary_accuracy: 0.9834
#
# Epoch 00040: val_loss improved from -0.96692 to -0.96700, saving model to cxr_reg_weights.best.hdf5
# Epoch 41/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9666 - dice_coef: 0.9666 - binary_accuracy: 0.9832 - val_loss: -0.9667 - val_dice_coef: 0.9667 - val_binary_accuracy: 0.9832
#
# Epoch 00041: val_loss did not improve from -0.96700
# Epoch 42/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9666 - dice_coef: 0.9666 - binary_accuracy: 0.9832 - val_loss: -0.9668 - val_dice_coef: 0.9668 - val_binary_accuracy: 0.9832
#
# Epoch 00042: val_loss did not improve from -0.96700
# Epoch 43/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9667 - dice_coef: 0.9667 - binary_accuracy: 0.9833 - val_loss: -0.9670 - val_dice_coef: 0.9670 - val_binary_accuracy: 0.9833
#
# Epoch 00043: val_loss improved from -0.96700 to -0.96705, saving model to cxr_reg_weights.best.hdf5
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-05.
# Epoch 44/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9669 - dice_coef: 0.9669 - binary_accuracy: 0.9834 - val_loss: -0.9670 - val_dice_coef: 0.9670 - val_binary_accuracy: 0.9833
#
# Epoch 00044: val_loss did not improve from -0.96705
# Epoch 45/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9671 - dice_coef: 0.9671 - binary_accuracy: 0.9834 - val_loss: -0.9670 - val_dice_coef: 0.9670 - val_binary_accuracy: 0.9833
#
# Epoch 00045: val_loss improved from -0.96705 to -0.96705, saving model to cxr_reg_weights.best.hdf5
# Epoch 46/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9671 - dice_coef: 0.9671 - binary_accuracy: 0.9834 - val_loss: -0.9670 - val_dice_coef: 0.9670 - val_binary_accuracy: 0.9833
#
# Epoch 00046: val_loss did not improve from -0.96705
# Epoch 47/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9671 - dice_coef: 0.9671 - binary_accuracy: 0.9834 - val_loss: -0.9670 - val_dice_coef: 0.9670 - val_binary_accuracy: 0.9833
#
# Epoch 00047: val_loss did not improve from -0.96705
#
# Epoch 00047: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-06.
# Epoch 48/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9673 - dice_coef: 0.9673 - binary_accuracy: 0.9836 - val_loss: -0.9669 - val_dice_coef: 0.9669 - val_binary_accuracy: 0.9832
#
# Epoch 00048: val_loss did not improve from -0.96705
# Epoch 49/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9673 - dice_coef: 0.9673 - binary_accuracy: 0.9836 - val_loss: -0.9671 - val_dice_coef: 0.9671 - val_binary_accuracy: 0.9834
#
# Epoch 00049: val_loss improved from -0.96705 to -0.96709, saving model to cxr_reg_weights.best.hdf5
# Epoch 50/50
# 569/569 [==============================] - 21s 36ms/step - loss: -0.9674 - dice_coef: 0.9674 - binary_accuracy: 0.9836 - val_loss: -0.9669 - val_dice_coef: 0.9669 - val_binary_accuracy: 0.9833
#
# Epoch 00050: val_loss did not improve from -0.96709

# %% [markdown]
# ## Plot the metric and evaluate

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize = (10, 5))
ax1.plot(loss_history.history['loss'], '-', label = 'Loss')
ax1.plot(loss_history.history['val_loss'], '-', label = 'Validation Loss')
ax1.legend()

ax2.plot(100*np.array(loss_history.history['binary_accuracy']), '-',
         label = 'Accuracy')
ax2.plot(100*np.array(loss_history.history['val_binary_accuracy']), '-',
         label = 'Validation Accuracy')
ax2.legend()

# %% [markdown]
# ## Test the model

# %%
pred_candidates = np.random.randint(1,validation_vol.shape[0],10)
preds = model.predict(validation_vol)

plt.figure(figsize=(20,10))

for i in range(0,9,3):
    plt.subplot(3,3,i+1)

    plt.imshow(np.squeeze(validation_vol[pred_candidates[i]]))
    plt.xlabel("Base Image")


    plt.subplot(3,3,i+2)
    plt.imshow(np.squeeze(validation_seg[pred_candidates[i]]))
    plt.xlabel("Mask")

    plt.subplot(3,3,i+3)
    plt.imshow(np.squeeze(preds[pred_candidates[i]]))
    plt.xlabel("Pridiction")
